# %%
from src.address_matching.normalization.normalize_address import AddressNormalizer

# %%
normalizer = AddressNormalizer()

# %%
addresses = [
    "Tugcular sokak tugce yucel mahallesi",
    "Barış Mah. 4178 sk. no:12 daire:5",
    "Çınarlı mah sokak 10 4/2",
    "Erzene mahallesi 1234 sokak no:7 Bornova İzmir",
    "mah 9876. sk. no:2 daire 1"
]

for address in addresses:
    print("Original:", address)
    print("Normalized:", normalizer.normalize(address))
    print("---")
# Out:
# Original: Tugcular sokak tugce yucel mahallesi
# Normalized: tugcular sk tugce yucel mah
# ---
# Original: Barış Mah. 4178 sk. no:12 daire:5
# Normalized: barış mah . 4178 sk . no : 12 daire : 5
# ---
# Original: Çınarlı mah sokak 10 4/2
# Normalized: çınarlı mah sk 10 4 / 2
# ---
# Original: Erzene mahallesi 1234 sokak no:7 Bornova İzmir
# Normalized: erzene mah 1234 sk no : 7 bornova izmir
# ---
# Original: mah 9876. sk. no:2 daire 1
# Normalized: mah 9876 . sk . no : 2 daire 1
# ---
